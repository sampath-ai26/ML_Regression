# %%
import pandas as pd
dataset=pd.read_csv("insurance_pre.csv")
dataset=pd.get_dummies(dataset,drop_first=True,dtype=int)
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
dependent=dataset[['charges']]

# %%
#from sklearn.model_selection import train_test_split
#x_train,x_test,y_train,y_test=train_test_split(independent,dependent,test_size=1/3,random_state=0)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid = { 'criterion' :['squared_error','absolute_error','friedman_mse'],
               'splitter' : ['best','random'],
               'max_features':[None,'sqrt','log2']
             }

grid = GridSearchCV(DecisionTreeRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(independent,dependent)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse'],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
#import matplotlib.pyplot as plt
#from sklearn import tree
#tree.plot_tree(regressor)
#plt.show()

# %%
# grid will handle r_score grid values and training and test data split internally.
#Hence seperate x_train, x_Test, ,y_train, y _test not required
re=grid.cv_results_
print("The R value for best params{}: " .format(grid.best_params_))
# Out:
# The R value for best params{'criterion': 'absolute_error', 'max_features': None, 'splitter': 'random'}:

# %%
table=pd.DataFrame.from_dict(re)
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.023811      0.003223         0.009235        0.002497
# 1        0.017081      0.003653         0.008699        0.002552
# 2        0.017559      0.004173         0.008389        0.002378
# 3        0.016252      0.000975         0.009838        0.001827
# 4        0.017826      0.001857         0.010468        0.001307
# 5        0.014728      0.001133         0.007616        0.001171
# 6        0.083576      0.003077         0.005981        0.000804
# 7        0.067323      0.003581         0.006766        0.001253
# 8        0.058243      0.005677         0.006416        0.001445
# 9        0.051369      0.003569         0.006243        0.001255
# 10       0.049029      0.002859         0.005989        0.001380
# 11       0.040484      0.005990         0.006556        0.000683
# 12       0.015818      0.000911         0.006412        0.001770
# 13       0.013023      0.001284         0.006805        0.000931
# 14       0.013356      0.001601         0.006684        0.001314
# 15       0.010725      0.001458         0.006477        0.000960
# 16       0.013279      0.000699         0.006391        0.000895
# 17       0.010705      0.001039         0.006182        0.001648
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               None           best
# 1    squared_error               None         random
# 2    squared_error               sqrt           best
# 3    squared_error               sqrt         random
# 4    squared_error               log2           best
# 5    squared_error               log2         random
# 6   absolute_error               None           best
# 7   absolute_error               None         random
# 8   absolute_error               sqrt           best
# 9   absolute_error               sqrt         random
# 10  absolute_error               log2           best
# 11  absolute_error               log2         random
# 12    friedman_mse               None           best
# 13    friedman_mse               None         random
# 14    friedman_mse               sqrt           best
# 15    friedman_mse               sqrt         random
# 16    friedman_mse               log2           best
# 17    friedman_mse               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.720890
# 1   {'criterion': 'squared_error', 'max_features':...           0.666998
# 2   {'criterion': 'squared_error', 'max_features':...           0.705739
# 3   {'criterion': 'squared_error', 'max_features':...           0.705979
# 4   {'criterion': 'squared_error', 'max_features':...           0.755746
# 5   {'criterion': 'squared_error', 'max_features':...           0.532298
# 6   {'criterion': 'absolute_error', 'max_features'...           0.720786
# 7   {'criterion': 'absolute_error', 'max_features'...           0.684350
# 8   {'criterion': 'absolute_error', 'max_features'...           0.716773
# 9   {'criterion': 'absolute_error', 'max_features'...           0.662429
# 10  {'criterion': 'absolute_error', 'max_features'...           0.673536
# 11  {'criterion': 'absolute_error', 'max_features'...           0.695373
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.717417
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.662662
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.702246
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.699646
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.717643
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.616864
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.610894           0.741471           0.731153
# 1            0.654257           0.678438           0.709294
# 2            0.630084           0.724920           0.739079
# 3            0.435750           0.716140           0.675838
# 4            0.624429           0.702232           0.689727
# 5            0.545472           0.713040           0.579853
# 6            0.585687           0.688996           0.708003
# 7            0.642636           0.736830           0.741796
# 8            0.537645           0.695790           0.734948
# 9            0.594057           0.720987           0.665350
# 10           0.622885           0.658152           0.729833
# 11           0.572929           0.670335           0.738397
# 12           0.645415           0.728500           0.710124
# 13           0.653395           0.676287           0.744433
# 14           0.603793           0.673289           0.692753
# 15           0.548660           0.565308           0.711693
# 16           0.637934           0.643379           0.721250
# 17           0.478564           0.742275           0.619482
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.681173         0.697116        0.047707                2
# 1            0.739961         0.689790        0.031011                6
# 2            0.646651         0.689295        0.043226                7
# 3            0.612383         0.629218        0.103281               16
# 4            0.685309         0.691489        0.041911                4
# 5            0.653295         0.604792        0.068508               18
# 6            0.750861         0.690867        0.056311                5
# 7            0.700686         0.701260        0.036418                1
# 8            0.611302         0.659292        0.074110               14
# 9            0.689633         0.666491        0.041880               13
# 10           0.748173         0.686516        0.046260               10
# 11           0.736484         0.682704        0.060594               11
# 12           0.680954         0.696482        0.029995                3
# 13           0.708628         0.689081        0.033410                8
# 14           0.706684         0.675753        0.037768               12
# 15           0.663677         0.637797        0.068053               15
# 16           0.715629         0.687167        0.038057                9
# 17           0.640791         0.619595        0.084139               17

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI : "))
children_input=int(input("Children:"))
sex_male_input=int(input("Sex Male 0 or1 :"))
smoker_yes_input=int(input("Smoker yes 0 or 1:"))
# Out:
# Age: 23
# BMI :  45
# Children: 3
# Sex Male 0 or1 : 1
# Smoker yes 0 or 1: 1

# %%
future_prediction=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Future prediction {}" .format(future_prediction))
# Out:
# Future prediction [44501.3982]
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
