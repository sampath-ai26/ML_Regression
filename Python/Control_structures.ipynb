# %%
age= int(input("Enter your age"))
# Out:
# Enter your age 59

# %%
if (age>18):
    print("adult")
else:
    print("Children")
# Out:
# adult

# %%
if (age<18):
    print("Children")
elif(age<35):
    print("Adult")
elif(age<59):
    print("Citizen")
else:
    print("Senior Citizen")
# Out:
# Senior Citizen

# %%
#for loop

# %%
lists=[23,43,56,45,66]

# %%
for temp in lists:
    print(temp)
# Out:
# 23
# 43
# 56
# 45
# 66

# %%
for age in lists:
    if (age<18):
        print("Children")
    elif(age<35):
        print("Adult")
    elif(age<59):
        print("Citizen")
    else:
        print("Senior Citizen")
# Out:
# Adult
# Citizen
# Citizen
# Citizen
# Senior Citizen

# %%
num=int(input("Enter any number"))
if(num%2==0):
    print("Even Number")
else:
    print("Odd Number")
# Out:
# Enter any number 33
# Odd Number

# %%
for i in range(1,5):
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
for i in range(20,30,3):
    print(i)
# Out:
# 20
# 23
# 26
# 29
