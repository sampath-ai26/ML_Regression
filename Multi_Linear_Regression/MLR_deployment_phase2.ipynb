# %%
import pickle

loaded_model=pickle.load(open("mlr_final_model.sav","rb"))
result=loaded_model.predict([[3434,54,56,1,0]])  # 5 inputs to be given here
result
# Out:
# C:\Anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[47923.9156021]])
